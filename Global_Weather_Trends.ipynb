# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
city_data = pd.read_csv('city_data.csv')

# %%
city_data.head()
# Out:
#    year     city        country  avg_temp
# 0  1849  Abidjan  Côte D'Ivoire     25.58
# 1  1850  Abidjan  Côte D'Ivoire     25.52
# 2  1851  Abidjan  Côte D'Ivoire     25.67
# 3  1852  Abidjan  Côte D'Ivoire       NaN
# 4  1853  Abidjan  Côte D'Ivoire       NaN

# %%
city_data.describe()
# Out:
#                year      avg_temp
# count  71311.000000  68764.000000
# mean    1905.799007     16.183876
# std       67.102099      7.592960
# min     1743.000000    -14.350000
# 25%     1858.000000      9.750000
# 50%     1910.000000     16.140000
# 75%     1962.000000     23.762500
# max     2013.000000     30.730000

# %%
# Check for number of null values
city_data.isnull().sum()
# Out:
# year           0
# city           0
# country        0
# avg_temp    2547
# dtype: int64

# %%
print(city_data[city_data.isnull().any(axis=1)])
# Out:
#        year          city               country  avg_temp
# 3      1852       Abidjan         Côte D'Ivoire       NaN
# 4      1853       Abidjan         Côte D'Ivoire       NaN
# 5      1854       Abidjan         Côte D'Ivoire       NaN
# 6      1855       Abidjan         Côte D'Ivoire       NaN
# 14     1863       Abidjan         Côte D'Ivoire       NaN
# 15     1864       Abidjan         Côte D'Ivoire       NaN
# 16     1865       Abidjan         Côte D'Ivoire       NaN
# 17     1866       Abidjan         Côte D'Ivoire       NaN
# 18     1867       Abidjan         Côte D'Ivoire       NaN
# 19     1868       Abidjan         Côte D'Ivoire       NaN
# 20     1869       Abidjan         Côte D'Ivoire       NaN
# 21     1870       Abidjan         Côte D'Ivoire       NaN
# 22     1871       Abidjan         Côte D'Ivoire       NaN
# 23     1872       Abidjan         Côte D'Ivoire       NaN
# 167    1845     Abu Dhabi  United Arab Emirates       NaN
# ...

# %%
city_list = pd.read_csv('city_list.csv')

# %%
city_list.head()
# Out:
#         city               country
# 0    Abidjan         Côte D'Ivoire
# 1  Abu Dhabi  United Arab Emirates
# 2      Abuja               Nigeria
# 3      Accra                 Ghana
# 4      Adana                Turkey

# %%
# Check if any null values
city_list.isnull().any()
# Out:
# city       False
# country    False
# dtype: bool

# %%
global_data = pd.read_csv('global_data.csv')

# %%
global_data.head()
# Out:
#    year  avg_temp
# 0  1750      8.72
# 1  1751      7.98
# 2  1752      5.78
# 3  1753      8.39
# 4  1754      8.47

# %%
global_data.describe()
# Out:
#               year    avg_temp
# count   266.000000  266.000000
# mean   1882.500000    8.369474
# std      76.931788    0.584747
# min    1750.000000    5.780000
# 25%    1816.250000    8.082500
# 50%    1882.500000    8.375000
# 75%    1948.750000    8.707500
# max    2015.000000    9.830000

# %%
global_data.isnull().any()
# Out:
# year        False
# avg_temp    False
# dtype: bool

# %%
# Explore unique cities in city_data
city_data['city'].unique()
# Out:
# array(['Abidjan', 'Abu Dhabi', 'Abuja', 'Accra', 'Adana', 'Adelaide',
#        'Agra', 'Ahmadabad', 'Albuquerque', 'Alexandria', 'Algiers',
#        'Allahabad', 'Almaty', 'Amritsar', 'Amsterdam', 'Ankara', 'Anshan',
#        'Antananarivo', 'Arlington', 'Asmara', 'Astana', 'Athens',
#        'Atlanta', 'Austin', 'Baghdad', 'Baku', 'Baltimore', 'Bamako',
#        'Bandung', 'Bangalore', 'Bangkok', 'Bangui', 'Barcelona',
#        'Barquisimeto', 'Barranquilla', 'Beirut', 'Belfast', 'Belgrade',
#        'Belo Horizonte', 'Benghazi', 'Berlin', 'Bern', 'Bhopal',
#        'Birmingham', 'Bissau', 'Boston', 'Bratislava', 'Brazzaville',
#        'Brisbane', 'Brussels', 'Bucharest', 'Budapest', 'Bujumbura',
#        'Bursa', 'Cairo', 'Cali', 'Campinas', 'Canberra', 'Caracas',
#        'Cardiff', 'Casablanca', 'Changchun', 'Changzhou', 'Charlotte',
#        'Chelyabinsk', 'Chengdu', 'Chicago', 'Chisinau', 'Colombo',
#        'Colorado Springs', 'Columbus', 'Conakry', 'Copenhagen', 'Cordoba',
# ...

# %%
# Explore how many years datasets covers

print(sorted(city_data['year'].unique()))
# Out:
# [1743, 1744, 1745, 1746, 1747, 1748, 1749, 1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771, 1772, 1773, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1794, 1795, 1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1
# ...

# %%
print(sorted(global_data['year'].unique()))
# Out:
# [1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771, 1772, 1773, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1794, 1795, 1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1
# ...

# %% [markdown]
# ## Global Weather Data Exploration

# %%
from pylab import rcParams
import statsmodels.api as sm

rcParams['figure.figsize'] = 11, 9
decomposed_avg_temp = sm.tsa.seasonal_decompose(global_data['avg_temp'],freq=1)
figure = decomposed_avg_temp.plot()
plt.show()

# %% [markdown]
# You can clearly see an upward trend in global avg temperatures.

# %%
rcParams['figure.figsize'] = 16, 6
white_noise = np.random.normal(loc=0, scale=1, size=1000)
plt.plot(white_noise)

# %% [markdown]
# A stationary time series is one whose statistical properties such as mean, variance, autocorrelation, etc. are all constant over time.
#
# - Strong stationarity: is a stochastic process whose unconditional joint probability distribution does not change when shifted in time. Consequently, parameters such as mean and variance also do not change over time.
#
# - Weak stationarity: is a process where mean, variance, autocorrelation are constant throughout the time

# %%
# The original non-stationary plot

decomposed_avg_temp.trend.plot()

# %%
# New stationary plot

decomposed_avg_temp.trend.diff().plot()

# %% [markdown]
# ## NYC Moving Average Analysis

# %%
nyc = city_data[city_data['city'] == 'New York']
print(nyc)
# Out:
#        year      city        country  avg_temp
# 46341  1743  New York  United States      3.26
# 46342  1744  New York  United States     11.66
# 46343  1745  New York  United States      1.13
# 46344  1746  New York  United States       NaN
# 46345  1747  New York  United States       NaN
# 46346  1748  New York  United States       NaN
# 46347  1749  New York  United States       NaN
# 46348  1750  New York  United States     10.07
# 46349  1751  New York  United States     10.79
# 46350  1752  New York  United States      2.81
# 46351  1753  New York  United States      9.52
# 46352  1754  New York  United States      9.88
# 46353  1755  New York  United States      6.61
# 46354  1756  New York  United States      9.94
# 46355  1757  New York  United States      8.89
# 46356  1758  New York  United States      8.15
# 46357  1759  New York  United States      9.01
# 46358  1760  New York  United States      7.73
# 46359  1761  New York  United States     10.18
# ...

# %%
nyc.dropna()
nyc['moving_avg_nyc'] = nyc['avg_temp'].rolling(window=5).mean()
# Out:
# /home/asun/.local/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
nyc2 = nyc.merge(global_data, left_on = 'year', right_on = 'year', how = 'left')

# %%
nyc2['moving_avg_global'] = nyc2['avg_temp_y'].rolling(window=5).mean()

# %%
print(nyc2)
# Out:
#      year      city        country  avg_temp_x  moving_avg_nyc  avg_temp_y  \
# 0    1743  New York  United States        3.26             NaN         NaN
# 1    1744  New York  United States       11.66             NaN         NaN
# 2    1745  New York  United States        1.13             NaN         NaN
# 3    1746  New York  United States         NaN             NaN         NaN
# 4    1747  New York  United States         NaN             NaN         NaN
# 5    1748  New York  United States         NaN             NaN         NaN
# 6    1749  New York  United States         NaN             NaN         NaN
# 7    1750  New York  United States       10.07             NaN        8.72
# 8    1751  New York  United States       10.79             NaN        7.98
# 9    1752  New York  United States        2.81             NaN        5.78
# 10   1753  New York  United States        9.52             NaN        8.39
# ...

# %%
nyc2.dropna()
# Out:
#      year      city        country  avg_temp_x  moving_avg_nyc  avg_temp_y  \
# 11   1754  New York  United States        9.88           8.614        8.47
# 12   1755  New York  United States        6.61           7.922        8.36
# 13   1756  New York  United States        9.94           7.752        8.85
# 14   1757  New York  United States        8.89           8.968        9.02
# 15   1758  New York  United States        8.15           8.694        6.74
# 16   1759  New York  United States        9.01           8.520        7.99
# 17   1760  New York  United States        7.73           8.744        7.19
# 18   1761  New York  United States       10.18           8.792        8.77
# 19   1762  New York  United States        9.55           8.924        8.61
# 20   1763  New York  United States        7.23           8.740        7.50
# 21   1764  New York  United States        9.55           8.848        8.40
# ...

# %%
nyc2['moving_avg_var'] = nyc2['moving_avg_nyc']- nyc2['moving_avg_global']

# %%
x = nyc2['year']

plt.plot(x, nyc2['moving_avg_nyc'], 'b--', label = 'nyc_5yr_rolling_avg', linewidth = 3.0)
plt.plot(x, nyc2['moving_avg_global'], 'c--', label = 'global_5yr_rolling_avg', linewidth = 3.0)
plt.fill_between(x, nyc2['moving_avg_global'], nyc2['moving_avg_nyc'], facecolor = 'green')

plt.xlabel('Year')
plt.ylabel('Temp')
plt.legend()

# %%
# Calculate Correlation Coefficient between average NYC and Global temperatures 

nyc2['moving_avg_nyc'].corr(nyc2['moving_avg_global'], method = 'pearson')
# Out:
# 0.8120442262311515

# %%
nyc2['avg_temp_x'].corr(nyc2['avg_temp_y'], method = 'pearson')
# Out:
# 0.5634132512382904

# %% [markdown]
# ## Initial Takeways (WIP)
#
# NYC and Global rolling average temperatures have a positive correlation coefficient of 81%.  NYC is typically warmer than the global average, and the variance appears to be slightly wider in more recent years (show statistical variations)
